# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
batch_size=128
train_iter,test_iter=d2l.load_data_fashion_mnist(batch_size,resize=224)#输入的图像像素是224x224

# %%
net=nn.Sequential(
    nn.Conv2d(1,96,kernel_size=11,stride=4),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3,stride=2),
    nn.Conv2d(96,256,kernel_size=5,padding=2),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3,stride=2),
    nn.Conv2d(256,384,kernel_size=3,padding=1),
    nn.ReLU(),
    nn.Conv2d(384,384,kernel_size=3,padding=1),
    nn.ReLU(),
    nn.Conv2d(384,256,kernel_size=3,padding=1,),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3,stride=2),
    nn.Flatten(),
    nn.Linear(6400,4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096,4096),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(4096,10),
)

# %%
X=torch.randn(1,1,224,224)
for layer in net:
    X=layer(X)
    print(print(layer.__class__.__name__,'output shape:\t',X.shape))
X
# Out:
# Conv2d output shape:	 torch.Size([1, 96, 54, 54])
# None
# ReLU output shape:	 torch.Size([1, 96, 54, 54])
# None
# MaxPool2d output shape:	 torch.Size([1, 96, 26, 26])
# None
# Conv2d output shape:	 torch.Size([1, 256, 26, 26])
# None
# ReLU output shape:	 torch.Size([1, 256, 26, 26])
# None
# MaxPool2d output shape:	 torch.Size([1, 256, 12, 12])
# None
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# None
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# None
# Conv2d output shape:	 torch.Size([1, 384, 12, 12])
# None
# ReLU output shape:	 torch.Size([1, 384, 12, 12])
# None
# Conv2d output shape:	 torch.Size([1, 256, 12, 12])
# None
# ReLU output shape:	 torch.Size([1, 256, 12, 12])
# None
# MaxPool2d output shape:	 torch.Size([1, 256, 5, 5])
# None
# Flatten output shape:	 torch.Size([1, 6400])
# None
# Linear output shape:	 torch.Size([1, 4096])
# None
# ReLU output shape:	 torch.Size([1, 4096])
# None
# Dropout output shape:	 torch.Size([1, 4096])
# None
# ...

# %%
lr=0.01
num_epochs=10
d2l.train_ch6(net,train_iter,test_iter,num_epochs,lr,torch.device('cuda'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c11bb45b0b31> in <module>
#       1 lr=0.01
#       2 num_epochs=10
# ----> 3 d2l.train_ch6(net,train_iter,test_iter,num_epochs,lr,torch.device('cuda'))
#       4
#
# C:\Anaconda_install\envs\pytorch\lib\site-packages\d2l\torch.py in train_ch6(net, train_iter, test_iter, num_epochs, lr, device)
#     495             optimizer.step()
#     496             with torch.no_grad():
# --> 497                 metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
#     498             timer.stop()
#     499             train_l = metric[0] / metric[2]
#
# C:\Anaconda_install\envs\pytorch\lib\site-packages\d2l\torch.py in accuracy(y_hat, y)
#     224         y_hat = d2l.argmax(y_hat, axis=1)
#     225     cmp = d2l.astype(y_hat, y.dtype) == y
# --> 226     return float(d2l.reduce_sum(d2l.astype(cmp, y.dtype)))
# ...
